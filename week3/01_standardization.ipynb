# %%
import numpy as np

data_2d = np.array([[1, 10],
                    [2, 20],
                    [3, 30]])

### ここに各列ごとに標準化する処理を記述してください ###
data_2d_mean = np.mean(data_2d, axis=0)
data_2d_std = np.std(data_2d, axis=0)
standardized_data_2d = (data_2d - data_2d_mean) / data_2d_std

print("元の2次元データ:\n", data_2d)
print("標準化された2次元データ（列ごと）:\n", standardized_data_2d)
# Out:
# 元の2次元データ:
#  [[ 1 10]
#  [ 2 20]
#  [ 3 30]]
# 標準化された2次元データ（列ごと）:
#  [[-1.22474487 -1.22474487]
#  [ 0.          0.        ]
#  [ 1.22474487  1.22474487]]
